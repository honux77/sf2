# %%
import os
# os.chdir('pic')
files = os.listdir()
files
cfiles = [f for f in files if f[:-4].isdigit() and 'gif' in f]
cfiles
# Out:
# ['01.gif',
#  '02.gif',
#  '03.gif',
#  '04.gif',
#  '05.gif',
#  '06.gif',
#  '07.gif',
#  '08.gif',
#  '09.gif',
#  '10.gif',
#  '11.gif',
#  '12.gif',
#  '13.gif',
#  '14.gif',
#  '15.gif',
#  '16.gif',
#  '17.gif',
#  '18.gif',
#  '19.gif',
#  '20.gif',
#  '21.gif',
#  '22.gif',
#  '23.gif',
#  '24.gif',
#  '25.gif',
#  '26.gif',
#  '27.gif',
#  '28.gif',
#  '29.gif',
#  '30.gif',
#  '31.gif',
#  '32.gif',
#  '33.gif',
#  '34.gif',
#  '35.gif',
#  '36.gif',
#  '37.gif',
#  '38.gif',
#  '39.gif',
#  '40.gif',
#  '41.gif',
#  '42.gif',
#  '43.gif']

# %%
type(files[0])
# Out:
# str

# %%
for cfile in cfiles:
    tempname = "temp.zzz"
    os.rename(cfile, tempname)
    os.rename(tempname, cfile.upper())

# %%
os.listdir()
# Out:
# ['01.GIF',
#  '02.GIF',
#  '03.GIF',
#  '04.GIF',
#  '05.GIF',
#  '06.GIF',
#  '07.GIF',
#  '08.GIF',
#  '09.GIF',
#  '10.GIF',
#  '10.jpg',
#  '102.jpg',
#  '103.jpg',
#  '105.jpg',
#  '107.jpg',
#  '108.jpg',
#  '109.jpg',
#  '11.GIF',
#  '11.jpg',
#  '110.jpg',
#  '111.jpg',
#  '112.jpg',
#  '113.jpg',
#  '114.jpg',
#  '116.jpg',
#  '117.jpg',
#  '118.jpg',
#  '119.jpg',
#  '12.GIF',
#  '12.jpg',
#  '120.jpg',
#  '121.jpg',
#  '125.jpg',
#  '13.GIF',
#  '13.jpg',
#  '14.GIF',
#  '14.jpg',
#  '15.GIF',
#  '15.jpg',
#  '16.GIF',
#  '16.jpg',
#  '17.GIF',
#  '17.jpg',
#  '18.GIF',
#  '18.jpg',
#  '19.GIF',
#  '19.jpg',
#  '2.jpg',
#  '20.GIF',
#  '20.jpg',
#  '21.GIF',
#  '21.jpg',
#  '22.GIF',
#  '22.jpg',
#  '23.GIF',
#  '23.jpg',
#  '24.GIF',
#  '24.jpg',
#  '25.GIF',
#  '25.jpg',
#  '26.GIF',
#  '26.jpg',
#  '27.GIF',
#  '27.jpg',
#  '28.GIF',
#  '28.jpg',
#  '29.GIF',
#  '29.jpg',
#  '3.jpg',
#  '30.GIF',
#  '30.jpg',
#  '31.GIF',
#  '31.jpg',
#  '32.GIF',
#  '32.jpg',
# ...

# %%
# Out:
# True
